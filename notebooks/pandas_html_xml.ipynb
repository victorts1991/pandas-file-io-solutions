# %%
import pandas as pd

# %%
df_html = pd.read_html('../data/filmes_wikipedia.html')

# o read_html procura pelas tags tables dentro do html e cria um elemento de uma lista para cada.
# No caso aqui temos 3 tabelas nesse html
len(df_html)
# Out:
# 3

# %%
top_filmes = df_html[1]

top_filmes.head()
# Out:
#                  Film  Release year              Director  \
# 0        Citizen Kane          1941          Orson Welles
# 1          Casablanca          1942        Michael Curtiz
# 2       The Godfather          1972  Francis Ford Coppola
# 3  Gone with the Wind          1939        Victor Fleming
# 4  Lawrence of Arabia          1962            David Lean
#
#                      Production companies  Rank
# 0                      RKO Radio Pictures     1
# 1                   Warner Bros. Pictures     2
# 2  Paramount Pictures, Alfran Productions     3
# 3         Selznick International Pictures     4
# 4                        Horizon Pictures     5

# %%
top_filmes.to_html('../data/top_filmes.html')

top_filmes_2 = pd.read_html('../data/top_filmes.html')

top_filmes_2[0].head()
# Out:
#    Unnamed: 0                Film  Release year              Director  \
# 0           0        Citizen Kane          1941          Orson Welles
# 1           1          Casablanca          1942        Michael Curtiz
# 2           2       The Godfather          1972  Francis Ford Coppola
# 3           3  Gone with the Wind          1939        Victor Fleming
# 4           4  Lawrence of Arabia          1962            David Lean
#
#                      Production companies  Rank
# 0                      RKO Radio Pictures     1
# 1                   Warner Bros. Pictures     2
# 2  Paramount Pictures, Alfran Productions     3
# 3         Selznick International Pictures     4
# 4                        Horizon Pictures     5

# %%
# Agora vamos passar ese html para um csv
top_filmes.to_csv('../data/top_filmes.csv', index=False)

top_filmes_csv = pd.read_csv('../data/top_filmes.csv')

top_filmes_csv.head()
# Out:
#                  Film  Release year              Director  \
# 0        Citizen Kane          1941          Orson Welles
# 1          Casablanca          1942        Michael Curtiz
# 2       The Godfather          1972  Francis Ford Coppola
# 3  Gone with the Wind          1939        Victor Fleming
# 4  Lawrence of Arabia          1962            David Lean
#
#                      Production companies  Rank
# 0                      RKO Radio Pictures     1
# 1                   Warner Bros. Pictures     2
# 2  Paramount Pictures, Alfran Productions     3
# 3         Selznick International Pictures     4
# 4                        Horizon Pictures     5

# %%
df_imdb = pd.read_xml('../data/imdb_top_1000.xml')

df_imdb.head()
# Out:
#    index                                        Poster_Link  \
# 0      0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1      1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2      2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3      3  https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4      4  https://m.media-amazon.com/images/M/MV5BMWU4N2...
#
#                Series_Title Released_Year Certificate  Runtime  \
# 0  The Shawshank Redemption          1994           A  142 min
# 1             The Godfather          1972           A  175 min
# 2           The Dark Knight          2008          UA  152 min
# 3    The Godfather: Part II          1974           A  202 min
# 4              12 Angry Men          1957           U   96 min
#
#                   Genre  IMDB_Rating  \
# 0                 Drama          9.3
# 1          Crime, Drama          9.2
# 2  Action, Crime, Drama          9.0
# 3          Crime, Drama          9.0
# ...

# %%
df_imdb.to_xml('../data/imdb2.xml')

df_imdb2 = pd.read_xml('../data/imdb2.xml')

df_imdb2.head()
# Out:
#    level_0  index                                        Poster_Link  \
# 0        0      0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1        1      1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2        2      2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3        3      3  https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4        4      4  https://m.media-amazon.com/images/M/MV5BMWU4N2...
#
#                Series_Title Released_Year Certificate  Runtime  \
# 0  The Shawshank Redemption          1994           A  142 min
# 1             The Godfather          1972           A  175 min
# 2           The Dark Knight          2008          UA  152 min
# 3    The Godfather: Part II          1974           A  202 min
# 4              12 Angry Men          1957           U   96 min
#
#                   Genre  IMDB_Rating  \
# 0                 Drama          9.3
# 1          Crime, Drama          9.2
# 2  Action, Crime, Drama          9.0
# ...

# %%
df_numero_habitantes = pd.read_html('https://pt.wikipedia.org/wiki/Lista_de_pa%C3%ADses_por_popula%C3%A7%C3%A3o')

len(df_numero_habitantes)
# Out:
# 3

# %%
df_numero_habitantes[1].to_csv('../data/numero_habitantes.csv', index=False)

df_numero_habitantes_csv = pd.read_csv('../data/numero_habitantes.csv')

df_numero_habitantes_csv.head()
# Out:
#   vdeListas de países                              vdeListas de países.1
# 0            Ambiente  Bem-estar sustentável Desempenho ambiental Emi...
# 1             Códigos  COI FIFA FIPS ISO Prefixo naval Telefônicos TL...
# 2          Demografia  Esperança de vida Fecundidade Imigrantes Morta...
# 3            Economia  Capacidade Nacional Capital Humano Competitivi...
# 4             Consumo  Bebidas Cerveja Idade legal Cannabis Adultos C...
